[-0.10, 96.78, 47.28],
[-0.12, 97.36, 47.58],
[-0.14, 96.82, 52.11],
[-0.27, 95.86, 63.90],
[-0.25, 95.58, 62.92],
[-0.20, 94.68, 59.74],
[-0.18, 95.58, 56.68],
[-0.25, 96.40, 61.87],
[-0.27, 96.38, 62.91],
[-0.24, 96.20, 61.05],
[-0.21, 95.14, 60.14],
[-0.21, 96.04, 58.96],
[-0.17, 96.40, 54.76],
[-0.25, 96.46, 61.46]]

# %%
test4=[
[-0.18, 94.8, 57.77],
[-0.07, 95.7, 45.66],
[-0.08, 97.5, 43.17],
[-0.15, 96.0, 53.57],
[-0.13, 95.1, 52.64],
[-0.19, 95.7, 58.10],
[-0.21, 96.7, 58.60],
[-0.17, 96.5, 54.90],
[-0.10, 97.1, 47.08],
[-0.25, 96.2, 62.35],
[-0.18, 95.7, 58.29],
[-0.18, 97.1, 54.54],
[-0.23, 96.1, 60.35],
[-0.17, 96.0, 55.24],
[-0.10, 95.2, 50.65],
[-0.15, 96.6, 52.18],
[-0.12, 96.6, 48.69],
[-0.15, 95.8, 52.73],
[-0.13, 96.4, 50.68],
[-0.16, 97.4, 52.04],
[-0.21, 96.5, 57.72],
[-0.20, 96.1, 57.73],
[-0.10, 93.8, 52.37],
[-0.13, 97.3, 49.54],
[-0.14, 97.2, 49.90],
[-0.11, 95.3, 51.82],
[-0.14, 96.4, 51.90],
[-0.24, 96.4, 60.52],
[-0.24, 95.7, 61.91]]

# %%
trial, score, accuracy, sparsity = [], [], [], []
best_trial = 0
best_score = 100
best_accur = 0
best_spars = 0
for i, [sco, accu, spar] in enumerate(test3):
    trial.append(i+1)
    score.append(sco)
    accuracy.append(accu)
    sparsity.append(spar)
    if sco < best_score:
        best_trial = i+1
        best_score = sco
        best_accur = accu
        best_spars = spar
    
fig, left_axis=plt.subplots()
right_axis = left_axis.twinx()

p1 = left_axis.plot(trial,accuracy, 'r.-', label='accuracy')
p2 = left_axis.plot(trial,sparsity, 'g.-', label='sparsity')
p3 = right_axis.plot(trial,score, 'b.-', label='score')

left_axis.set_xlabel('Trial')
left_axis.set_ylabel('Accuracy/Sparsity (%)')
right_axis.set_ylabel('Score (lower is better)')

lines = p1+p2+p3
labs = [l.get_label() for l in lines]
left_axis.legend(lines, labs, loc=6)

left_axis.plot(best_trial,best_accur, 'ro')
left_axis.plot(best_trial,best_spars, 'go')
right_axis.plot(best_trial,best_score, 'bo')

left_axis.annotate('({},{})'.format(best_trial, best_accur), xy=(best_trial, best_accur))
left_axis.annotate('({},{})'.format(best_trial, best_spars), xy=(best_trial, best_spars))
right_axis.annotate('({},{})'.format(best_trial, best_score), xy=(best_trial, best_score))
             
left_axis.grid()

# %%
def plot_pareto_frontier(Xs, Ys, maxX=True, maxY=True):
    '''Pareto frontier selection process'''
    sorted_list = sorted([[Xs[i], Ys[i]] for i in range(len(Xs))], reverse=maxY)
    pareto_front = [sorted_list[0]]
    for pair in sorted_list[1:]:
        if maxY:
            if pair[1] >= pareto_front[-1][1]:
                pareto_front.append(pair)
        else:
            if pair[1] <= pareto_front[-1][1]:
                pareto_front.append(pair)
    
    '''Plotting process'''
    T = np.arctan2(Ys,Xs)
    plt.scatter(Xs, Ys, s=75, c=T, alpha=.5)
    pf_X = [pair[0] for pair in pareto_front]
    pf_Y = [pair[1] for pair in pareto_front]
    plt.plot(pf_X, pf_Y)
    plt.xlabel("Sparsity (%)")
    plt.ylabel("Accuracy (%)")
    plt.title("TPE w/ constraint")
    plt.grid()
    plt.show()
    
plot_pareto_frontier(sparsity, accuracy)
